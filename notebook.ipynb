# %%
import yfinance as yf
import pandas as pd

df = yf.download("AAPL", period="1mo", interval="1d")
df = df.reset_index()  
print(df.columns)

print(df.head())
df.columns = df.columns.get_level_values("Price")
df.columns.name = None
print(df.head())
print(df.columns)
# Out:
# C:\Users\smpop\AppData\Local\Temp\ipykernel_18500\4005636785.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", period="1mo", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([(  'Date',     ''),
#             ( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])
# Price        Date       Close        High         Low        Open    Volume
# Ticker                   AAPL        AAPL        AAPL        AAPL      AAPL
# 0      2025-10-29  269.438812  271.147148  266.851294  269.019206  51086700
# 1      2025-10-30  271.137146  273.874513  268.219991  271.726571  69886500
# 2      2025-10-31  270.108154  277.051436  268.899335  276.721738  86167100
# 3      2025-11-03  268.789429  270.587704  265.992153  270.158128  50194600
# 4      2025-11-04  269.778473  271.227050  267.360803  268.070107  49274800
#         Date       Close        High         Low        Open    Volume
# 0 2025-10-29  269.438812  271.147148  266.851294  269.019206  51086700
# 1 2025-10-30  271.137146  273.874513  268.219991  271.726571  69886500
# 2 2025-10-31  270.108154  277.051436  268.899335  276.721738  86167100
# 3 2025-11-03  268.789429  270.587704  265.992153  270.158128  50194600
# 4 2025-11-04  269.778473  271.227050  267.360803  268.070107  49274800
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
import warnings 

def compute_daily_returns(df):
    df = df.copy()
    df["Return"] = df["Close"].pct_change()
    return df
df=compute_daily_returns(df)
def summary_stats(df):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")

    first = df["Close"].iloc[0]
    last = df["Close"].iloc[-1]

    full_return = (last / first) - 1
    stats =  {
        "Mean return": float(df["Return"].mean()),
        "Volatility": float(df["Return"].std()),
        "Min price": float(df["Close"].min()),
        "Max price": float(df["Close"].max()),
        "Full return": float(full_return)
    }
    return pd.DataFrame(
        [(k, v) for k, v in stats.items()],
        columns=["Metric", "Value"]
    )
summary_stats(df)
# Out:
# C:\Users\smpop\AppData\Local\Temp\ipykernel_18500\2551249508.py:19: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "Min price": float(df["Close"].min()),
# C:\Users\smpop\AppData\Local\Temp\ipykernel_18500\2551249508.py:20: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "Max price": float(df["Close"].max()),
# C:\Users\smpop\AppData\Local\Temp\ipykernel_18500\2551249508.py:21: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "Full return": float(full_return)
#         Metric       Value
# 0  Mean return    0.001677
# 1   Volatility    0.009248
# 2    Min price  266.250000
# 3    Max price  278.850006
# 4  Full return    0.034929
